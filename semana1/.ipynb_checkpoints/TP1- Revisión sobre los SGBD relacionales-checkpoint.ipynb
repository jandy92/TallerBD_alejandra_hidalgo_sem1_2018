# %% [markdown]
# # TP1- Revision sobre los SGBD relacionales

# %% [markdown]
# Para revisar algunos conceptos de los SGBD relacionales (en particular el modelo relacional y el lenguaje SQL), vamos a crear una pequeña Base de Datos relacional desde un programa en Python y a partir de datos que se encuentran en varios archivos textos.
#
# La base de datos que queremos construir está representada por el modelo Entidad-Asociación siguiente:

# %% [markdown]
# <img src="modeloEA-1.png">

# %% [markdown]
# ## 1. Transformación del Modelo Entidad-Asociación hacia Modelo Relacional
#
# Proponer un modelo relacional que corresponde al modelo Entidad-Asociación.

# %% [markdown]
# Medios Prensa(PK Nombre, Dueño, Numero Followers)
# Noticias (PK ID, Titulo, Texto, #publicar, fecha)

# %% [markdown]
# ...

# %% [markdown]
# ## 2. Crear la estructura de la base de datos desde un programa Python

# %%
import sys
print(sys.version)
# Out:
# 3.6.1 |Anaconda 4.4.0 (64-bit)| (default, May 11 2017, 13:09:58)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]

# %% [markdown]
# ### 2.1 Conectarse a MySQL desde Python

# %%
import mysql.connector
config= {
    'user': 'root',
    'password': 'root',
    'host': 'localhost',
}
conector = mysql.connector.connect(**config)
cursor = conector.cursor()
try:
    cursor.execute("CREATE DATABASE tp1")

except Exception as db_creation:
    print(db_creation)

cursor.close()
conector.close()

# %% [markdown]
# # 2.2 Crear las tablas

# %%
import mysql.connector
config= {
    'user': 'root',
    'password': 'root',
    'host': 'localhost',
    'database': 'tp1',
}
conector = mysql.connector.connect(**config)
cursor = conector.cursor()

cursor.execute('CREATE TABLE medios_prensa ('
    'nombre VARCHAR(20) NOT NULL PRIMARY KEY,'
    'dueno VARCHAR(150),'
    'numero_followers INTEGER);'
    )
conector.commit()
cursor.execute('CREATE TABLE noticias ('
    'id INTEGER PRIMARY KEY  AUTO_INCREMENT,'
    'titulo VARCHAR(200),'
    'texto TEXT,'
    'publicar VARCHAR(20) NOT NULL,'
    'fecha DATETIME,'
    'FOREIGN KEY (publicar) REFERENCES medios_prensa(nombre)'
    ');'
)  

conector.commit()
cursor.close()
conector.close()

# %% [markdown]
# # 3. Insertar los datos en la base de datos

# %% [markdown]
# ## 3.1 Leer los archivos textos

# %%
import mysql.connector
config= {
    'user': 'root',
    'password': 'root',
    'host': 'localhost',
    'database': 'tp1',
}
conector = mysql.connector.connect(**config)
cursor = conector.cursor()


medios_data=[]

with open("medios.csv","r") as file:
    file.readline()
    datos = file.readlines()
    for d in datos:
        lista = d.split(',')
        medios_data.append(tuple((lista[0],lista[1],lista[2].replace('\n',''))))
        
query = 'INSERT INTO medios_prensa(nombre,dueno,numero_followers) VALUES(%s,%s,%s);'
try:
    cursor.executemany(query,medios_data)
    conector.commit()
except Exception as ex:
    print('exception inserting medios_prensa')

# %%
import mysql.connector
config= {
    'user': 'root',
    'password': 'root',
    'host': 'localhost',
    'database': 'tp1',
}
conector = mysql.connector.connect(**config)
cursor = conector.cursor()

noticias_data=[]
with open("noticias.txt","r") as file:
    lineas=file.readlines()
    i=0
    c = 0
    noticia={}
    while(i<len(lineas)):
        if(lineas[i] != '----------\n'):
            if(c == 0):
                noticia['fecha'] = lineas[i].replace('\n','')
            elif(c == 1):
                noticia['medio'] = lineas[i].replace('\n','')
            elif(c == 2):
                noticia['titulo'] = lineas[i].replace('\n','')
            elif(c == 3):
                noticia['contenido'] = lineas[i].replace('\n','')
            c = c+1
        else:
            #noticias.append(noticia)
            noticias_data.append((noticia['fecha'],noticia['medio'],noticia['titulo'],noticia['contenido']))
            c = 0
        i = i +1;

try:
    query = 'INSERT INTO noticias(fecha,publicar,titulo,texto) VALUES(%s,%s,%s,%s);'
    cursor.executemany(query,noticias_data) 
    conector.commit()
except Exception as ex:
    print('exception inserting noticias',ex)
cursor.close()
conector.close()

# %% [markdown]
# ## 3.2 Leer los archivos textos y insertar los datos

# %% [markdown]
# Está hecho arriba

# %% [markdown]
# # 4. Consultar la base de datos

# %% [markdown]
# Listar los medios de prensa en Chile ordenado según su número de followers en Twitter.

# %%
import mysql.connector
config= {
    'user': 'root',
    'password': 'root',
    'host': 'localhost',
    'database': 'tp1',
}
conector = mysql.connector.connect(**config)
cursor = conector.cursor()

query='SELECT nombre, numero_followers FROM medios_prensa ORDER BY numero_followers DESC'

cursor.execute(query)
for (nombre,numero_followers) in cursor:
    print(nombre,numero_followers)

cursor.close()
conector.close()
# Out:
# 24HorasTVN 3286603
# TVN 2910624
# T13 2869408
# CNNChile 2814705
# biobio 2756031
# Cooperativa 2638045
# canal13 2089537
# latercera 1849215
# Emol 1805524
# adnradiochile 1660965
# thecliniccl 1637257
# elmostrador 1533717
# chilevision  1264464
# terraChile 1190512
# Mega 1016622
# ahoranoticiasAN 1012851
# ciper 902201
# PublimetroChile 876749
# lacuarta 763174
# deportes13cl 610516
# La_Segunda 563406
# LaRedTV 531088
# el_dinamo 418425
# chvdeportes 351803
# nacioncl 318346
# revistaQP 298495
# DiarioLaHora 296059
# El_Ciudadano 277703
# CadenaChile 277201
# ElGraficoChile 268826
# difamadores 248538
# biobiodeportes 235075
# Emol_Deportes 220974
# LaSerenaOnline 212759
# soychilecl 208424
# Dfinanciero 133828
# elquintopoder 130323
# mercuriovalpo 129761
# tvn_deportes 128555
# GlamoramaCL 121128
# eldia_cl 106078
# ElPeriscopioCL 105532
# elobservatodo 99838
# laterceracom 96775
# elsurcl  95662
# uchileradio 94999
# soyconcepcion 94205
# RadioPudahuel 88523
# biobiotv 88475
# soyvalparaiso 84203
# AustralTemuco 83479
# hoyxhoycl 83193
# RadioDuna 82363
# radiozero977 80399
# revistacapital 80101
# rvfradiopopular 79900
# chv_noticias 77309
# eldesconcierto 74403
# estadonacional  68410
# EmolTV 67772
# RADIOPALOMAFM 67531
# RedMiVoz 67071
# AgriculturaFM 65861
# pulso_tw 64516
# Estrategiacl 61664
# laestrellavalpo 61280
# TVChileTVN 55816
# FMConquistador 55301
# prensaopal  53500
# RevistaCosas 52971
# elliberocl 50472
# Ferplei 49410
# EYN_ELMERCURIO 45979
# araucanianews 45341
# Araucaniatv 45230
# RedMaule 44830
# radiolaclave 42733
# MauleNoticias 41294
# ElPeriodista 40308
# RedBiobio 38855
# diarioelcentro 38676
# ASChile  37956
# ucv_tv 36488
# MQLTV 35153
# maulee 34703
# ladiscusioncl 34062
# RadioNuble 33040
# mercurioafta 32817
# vlanoticia 32516
# elrancaguino 32375
# Diarioconce 31910
# soyarica 31905
# ellanquihue 31138
# elmartutino 30291
# CronicaChillan 29925
# laestrellaiqq 28825
# pinguinodiario 27526
# radiosantamaria 26697
# cronicacurico 26394
# elnortero 26079
# AconcaguaNews 25939
# soyantofagasta  25765
# soytemuco 25460
# Mapuexpress 25253
# eltipografo 25159
# eo_enlinea 25099
# austral_osorno 24627
# Azkintuwe 24625
# TVNRedMaule 24405
# estrellaconce 24097
# eldefinido 23590
# msncl 23353
# TVU_television  22604
# tvmaulinos 21995
# Red_OHiggins 21526
# LaTerceraTV 21373
# diarioafta 20984
# RadioSago 20928
# soyiquique 20612
# ChillanOnline 20581
# Diario_Pyme 20569
# radiochiloe 20435
# chiloealdia 20398
# chillanactivo 20158
# Clave9cl 20120
# emol_magazine 19538
# laotravoz 19422
# RadioPolar 19411
# austral_losrios 19382
# elrancahuaso 19298
# ElSembrador1047 18480
# Elperiodicocl 18422
# Osornonews 18272
# tentos 18250
# LaPrensAustral 18098
# cambio21cl 17593
# radiocondell 17486
# estrellachiloe 17152
# soypuertomontt 17076
# elmorrocotudo 17008
# LaProvinciaCL 16572
# soyosorno 16490
# NUBLEONLINE_ 16478
# EnLineaMaule 16320
# red_coquimbo 16225
# sitiocero 16096
# rioenlinea 16029
# RNuevoMundo 15860
# RedValparaiso 15649
# elepicentro 15595
# RedAraucania 15559
# diarioatacama 15432
# RedAntofagasta 15165
# ElBoyaldia 14868
# elrepuertero 14749
# RadioEstacion1 14717
# soychiloe 14693
# estrella_antofa 14297
# palabranoticia 14230
# elsoldeiquique 14104
# soyvaldiviacl 13903
# el_vacanudo 13862
# soychillan 13667
# elconcecuente 13639
# IquiqueRadioCL 13533
# laprensacurico 13507
# elnaveghable 12863
# talcanoticias 12756
# chanarcillo 12145
# elovallino  12085
# PrensaChiloe 11846
# soysanantonio 11733
# elaconcagua 11529
# lidersanantonio 11429
# el_serenense 11354
# laopinon 10722
# latribunacl 10548
# redloslagos 10470
# fundacionREM 10244
# radioquellon  10113
# InetTvDigital  10038
# ITVnoticias 9624
# soycalama 9621
# ELCLARINDECHILE 9595
# DiarioPenquista 9550
# Diarioenaccion  9547
# diarioelcoqbano 9432
# soycopiapo 9255
# rsumen 9061
# DigitalFMChile 8823
# elmagallanews 8136
# PutaendoInforma 8031
# DiarioOvalleHoy 7834
# ddivisadero 7757
# redatacama 7574
# RedlosRios 7546
# soyquillota 7377
# NorteMinero_CL 7309
# elsiglochile 7024
# TVCONTIVISION 6868
# EstrelladeArica 6617
# radiomaxima_fm 6424
# diarioeltrabajo 6108
# VozdelaCosta  6054
# elranco 5560
# AQUASocial 5373
# AtacamaNoticias 5116
# VTVCanal2 5079
# verdadahoracl 5048
# Elquiglobal 4955
# soytalcahuano 4933
# elqhaydecierto 4898
# agenciaunochile 4825
# osornotvmas 4811
# pdteIbanez 4576
# DigitalFmAntofa 4457
# radiopudeto 4419
# Publimetro_TV 4414
# Pagina7Chile 4340
# soyarauco 4313
# dichatoaldia 4158
# NatalesOnLine 4102
# soysancarlos 4040
# girovisualtv 3960
# carta_abierta 3905
# InforiosCL 3870
# radioptonatales 3702
# Estrella_Toco 3638
# estrella_loa 3544
# soycoronel 3418
# verticetv 3328
# RedArica 3327
# redcomunales 3208
# ElChelenko 3188
# cauquenesnet 3177
# soytome 3156
# elandacollino 3115
# lavozdemaipu 2989
# elamaule 2949
# cysradio 2800
# elpaihuanino 2698
# PrimitivosCL 2574
# Nacimentanocl 2499
# Prensamariquina 2333
# diariosenred 2298
# elvicunense 2170
# DiarioPaillaco  2167
# RReloncavi 2119
# panguipullinoti 2112
# la7talca 2044
# RadioCauquenes 1971
# Infomariquinacl 1937
# CCauqueninoCom 1836
# elparadiario14 1789
# puntofinal_cl 1673
# ElAriqueno 1646
# radionahuelbuta 1589
# elmontepatrino 1512
# el_bulnensino 1227
# elcombarbalino 1197
# el_salamanquino 1189
# FMPULSO 971
# elhurtadino 895
# CoolTV_Valdivia 872
# laperladelimari 751
# DiarioElComunal 668
# diariodeaysen 657
# elpunitaquino 560
# elvileno 553
# elcanelino 545
# elillapelino 315

# %% [raw]
# Contar los dueños de medios de prensa en Chile.

# %%
import mysql.connector
config= {
    'user': 'root',
    'password': 'root',
    'host': 'localhost',
    'database': 'tp1',
}
conector = mysql.connector.connect(**config)
cursor = conector.cursor()

query='SELECT COUNT(*) FROM ( SELECT dueno AS total FROM medios_prensa GROUP BY(dueno) ORDER BY dueno) as result;'

cursor.execute(query)
print("total",cursor.fetchall()[0][0])

cursor.close()
conector.close()
# Out:
# total 158

# %% [markdown]
# Contar cuantes medios de prensa posee cada dueño.

# %%
import mysql.connector
config= {
    'user': 'root',
    'password': 'root',
    'host': 'localhost',
    'database': 'tp1',
}
conector = mysql.connector.connect(**config)
cursor = conector.cursor()

query='SELECT dueno,COUNT(dueno) AS total FROM medios_prensa GROUP BY(dueno) ORDER BY DUENO'

cursor.execute(query)
for (nombre) in cursor:
    print(nombre)

cursor.close()
conector.close()
# Out:
# ('"Pedro Cayuqueo Enama"', 1)
# ('Aconcagua News', 1)
# ('Agencia Uno', 1)
# ('Albavisión (MX)', 1)
# ('Araucanía Noticias', 1)
# ('AraucaníaTV', 1)
# ('Benjamín González', 1)
# ('Betazeta Networks S.A.', 1)
# ('Bethia', 2)
# ('BIO-BIO comunicaciones', 1)
# ('Biobio Comunicaciones', 1)
# ('BS Comunicaciones', 1)
# ('Carta Abierta', 1)
# ('Cauquenes NET', 1)
# ("Centro Cultural de Comunicación y Educación Radiofónica ''Chasqui''", 1)
# ('CEPT Comunicaciones', 1)
# ('Chañarcillo', 1)
# ('Chillan Activo', 1)
# ('Chillan Noticias', 1)
# ('Chiloe Al día', 1)
# ('Clave9', 1)
# ('Colectivo de Comunicacion Mapuche Mapuexpress', 1)
# ('Compañía Chilena de Comunicaciones', 1)
# ('Compañía de Radio y TV Nuevo Mundo S.A', 1)
# ('Comunicaciones C Y V S A ', 1)
# ('Comunidad Sitio Cero', 1)
# ('Consorcio Periodístico El Epicentro S.A', 1)
# ('Consorcio Periodístico El Norte SpA', 1)
# ('CoolTV', 1)
# ('Diario El Sur S.A', 1)
# ('Diario El Sur S.A.', 1)
# ('Diario ELDIA', 1)
# ('Diario en Acción', 1)
# ('Diario Naciemiento', 1)
# ('Dichato al Dia', 1)
# ('Ediciones Giro País SpA', 1)
# ('Ediciones Punto Final', 1)
# ('Ediciones y Publicaciones Bobby S.A. ', 1)
# ('Ediciones y Publicaciones El Buen Aire S.A.', 1)
# ('Editorial Gestion', 1)
# ('Editorial Tiempo Presente Ltda.', 1)
# ('Eduardo Mardones', 1)
# ('El Aconcagua', 1)
# ('El bulnesino', 1)
# ('El cauquenino', 1)
# ('El Chelenko Comunicaciones', 1)
# ('El Definido', 1)
# ('EL DIARIO DE AYSEN S.A', 1)
# ('El Divisadero', 1)
# ('El Mercurio S.A.P', 27)
# ('El Mercurio S.A.P.', 20)
# ('El Periodico', 1)
# ('El Periodista S.A', 1)
# ('El Ranco', 1)
# ('El sol de Iquique', 1)
# ('El Tipógrafo SPA', 1)
# ('El Trabajo', 1)
# ('Elyon Comunicaciones', 1)
# ('Empresa de Publicaciones La Prensa Austral S.A.', 1)
# ('Empresa Periodística Bío-Bío Ltda.', 1)
# ('Empresa Periodística Curicó Ltda.', 1)
# ('Empresa Periodística El Centro S.A.', 1)
# ('Empresa Periodística El Observador Ltda', 1)
# ('Empresa Periodística La Nación S.A.', 2)
# ('En linea maule', 1)
# ('Estación 1', 1)
# ('Estado Chileno', 6)
# ('FM Pulso', 1)
# ('Francisco Pérez', 1)
# ('Fundacion CIPER- Grupo Copesa', 1)
# ('Fundacion Democracia y Desarrollo', 1)
# ('Fundación Presidente Allende', 1)
# ('Fundación Radio Estrella del Mar', 1)
# ('Giro visual', 1)
# ('Grupo Canal 13', 1)
# ('Grupo Claro', 2)
# ('Grupo Copesa', 10)
# ('Grupo Diario Sur', 1)
# ('Grupo Editorial Editec', 1)
# ('Grupo Luksic', 2)
# ('Grupo Mi Voz Red de Diarios Ciudadanos', 15)
# ('Grupo Mochiatti', 1)
# ('Grupo Mosciatti', 1)
# ('Grupo Prisa España', 1)
# ('Holding Octava Comunicaciones S.A.', 1)
# ('Ibero Americana Radio Chile', 3)
# ('Ilustre municipalidad de Osorno', 1)
# ('Inet TV', 1)
# ('InfoMariquina', 1)
# ('Inversiones y Publicaciones Comunidades Ciudadanas S. A.', 1)
# ('Inversiones y Publicaciones Comunidades Ciudadanas S.A.', 1)
# ('Iquique Radio', 1)
# ('ITV Patagonia Ltda.', 1)
# ('La 7', 1)
# ('La Discusión SA', 1)
# ('La Plaza S.A.', 1)
# ('La Serena Online', 1)
# ('La Voz de Maipú', 1)
# ('Medios de Television Contivision Limitada', 1)
# ('Merelec SpA ', 13)
# ('Metro International', 4)
# ('Microsoft Corporation. ', 1)
# ('Miguel Nasur', 1)
# ('N.E', 4)
# ('N.E.', 1)
# ('NOL Periodico', 1)
# ('Noticias Los Rios', 1)
# ('Núcleo de emisoras Paloma', 1)
# ('Obispado de Chillan', 1)
# ('Obispado Osorno?', 1)
# ('opal press', 1)
# ('OPEN GROUP COMUNICACIONES LTDA.', 1)
# ('Organización Comercial Radio Polar Ltda.', 1)
# ('Panguipulli Noticias', 1)
# ('Parroquia San José', 1)
# ('Partido Comunista de Chile', 1)
# ('Patagonica Publicaciones S.A.', 1)
# ('Penquista', 1)
# ('Pontificia Universidad Católica de Valparaiso', 1)
# ('Prensa Chiloe', 1)
# ('Prensa Mariquina', 1)
# ('Producciones y Asesorías Gou Infotaiment Limitada', 1)
# ('Putaendo Informa', 1)
# ('Radio Cauquenes', 1)
# ('Radio Máxima', 1)
# ('Radio Quellon', 1)
# ('Red de Diarios Comunales', 2)
# ('Red de Diarios Comunales Sociedad Limitada', 11)
# ('Red de Diarios Comunales Sociedad Limitada\xa0.', 3)
# ('Red de Emisoras Madripo', 1)
# ('Red de medios de comunicación digital Portales Regionales', 1)
# ('Resumen', 1)
# ('Rioenlinea', 1)
# ('Rodrigo Vidal', 1)
# ('Sociedad Agrícola y Ganadera de Osorno', 1)
# ('Sociedad Coronado y Sierpe LTDA.', 1)
# ('Sociedad de Comunicaciones Salto del Soldado Ltda', 1)
# ('Sociedad de Inversiones Vaccaro Collao e Hijos Ltda.', 1)
# ('Sociedad de Radio y Publicidad San Antonio Ltda.', 1)
# ('Sociedad Nacional de Agricultura', 1)
# ('SOCIEDAD PERIODÍSTICA BANIC Y LANCELLOTTI LTDA', 1)
# ('Sociedad Periodística Cambio S.A.', 1)
# ('Sociedad periodistica Crónica noticias SPA', 1)
# ('Sociedad Periodística El Ciudadano', 1)
# ('Sociedad Periodistica El Libero S.A.', 1)
# ('Sociedad René Salinas Palacios', 1)
# ('Sociedad sonido sur', 1)
# ('Terra Networks Chile S.A.', 1)
# ('Time Warner', 4)
# ('Trayectos Agencia de Comunicaciones Ltda', 1)
# ('Tv maulinos', 1)
# ('UdeC - Grupo Copesa', 1)
# ('Universidad de Chile', 1)
# ('Velásquez Hnos. y Cía. Ltda.', 1)
# ('Verdad Ahora', 1)
# ('Vértice Comunicaciones', 1)
# ('Vivimos la noticia', 1)
# ('Vocación-Comunitaria', 1)

# %% [markdown]
# Mostrar los últimos 10 títulos de noticias del medio "La Tercera"

# %%
import mysql.connector
config= {
    'user': 'root',
    'password': 'root',
    'host': 'localhost',
    'database': 'tp1',
}
conector = mysql.connector.connect(**config)
cursor = conector.cursor()

query='SELECT * FROM noticias WHERE publicar = \'latercera\' ORDER BY fecha DESC LIMIT 10;'

cursor.execute(query)
for (nombre) in cursor:
    print(nombre)

cursor.close()
conector.close()
# Out:
# (50, 'Cabo de Carabineros dispara a su pareja en hotel de Puerto Montt', 'Personal de la PDI investiga un grave incidente registrado durante la madrugada de este domingo en el\xa0Hotel Vicente Costanera de la ciudad de\xa0Puerto Montt, en la región de Los Lagos. Los primeros antecedentes indican que estando en una habitación del mencionado recinto, un Cabo Primero de la\xa0Quinta Comisaría de la ciudad habría disparado a su pareja tras una discusión. Tras ello, el funcionario se habría autoinferido un disparo en la cabeza.\xa0 Debido al complejo incidente, ambos fueron trasladados hasta el Hospital Regional de Puerto Montt, donde permanecen con diagnóstico reservado.\xa0 Desde la institución informaron que se inició un sumario interno.', 'latercera', datetime.datetime(2017, 5, 7, 12, 56, 47))

# %% [markdown]
# Mostrar los nombre de medios y los títulos en los cuales aparacen la palabra "Valdivia".

# %%
import mysql.connector
config= {
    'user': 'root',
    'password': 'root',
    'host': 'localhost',
    'database': 'tp1',
}
conector = mysql.connector.connect(**config)
cursor = conector.cursor()

query='SELECT publicar, titulo FROM noticias WHERE titulo LIKE "%valdivia%" ;'

cursor.execute(query)
for (nombre) in cursor:
    print(nombre)

cursor.close()
conector.close()

# %% [markdown]
# Por cada medio, mostrar el número de títulos en los cuales aparecen la palabra "Puerto Montt".

# %%
import mysql.connector
config= {
    'user': 'root',
    'password': 'root',
    'host': 'localhost',
    'database': 'tp1',
}
conector = mysql.connector.connect(**config)
cursor = conector.cursor()

query='SELECT publicar as medio, COUNT(*) as titulos FROM (SELECT * FROM noticias WHERE titulo LIKE "%Puerto montt%") as result GROUP BY PUBLICAR;'

cursor.execute(query)
for (nombre) in cursor:
    print(nombre)

cursor.close()
conector.close()
# Out:
# ('24HorasTVN', 2)
# ('adnradiochile', 8)
# ('biobio', 35)
# ('CNNChile', 1)
# ('latercera', 1)
# ('TerraChile', 1)
# ('thecliniccl', 1)
# ('TVN', 1)
